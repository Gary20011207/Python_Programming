# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 5, 0.1)
y = np.square(x)
plt.plot(x, y, "-")
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.square(x)
plt.plot(x, y, "--")
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.square(x)
plt.plot(x, y, "-.")
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.square(x)
plt.plot(x, y, ":")
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.square(x)
plt.plot(x, y, "o")
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.square(x)
plt.plot(x, y, "^")
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.square(x)
plt.plot(x, y, "D")
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.square(x)
plt.plot(x, y, "x")
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.square(x)
plt.plot(x, y, "ro")
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.square(x)
plt.plot(x, y, "g^")
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.square(x)
plt.plot(x, y, "bD")
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.square(x)
plt.plot(x, y, "cx")
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.square(x)
plt.plot(x, y, "ro-")
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.square(x)
plt.plot(x, y, "g--+")
plt.show()
